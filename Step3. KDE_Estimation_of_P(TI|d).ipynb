# %%
# import necessary package
from src.Select_TI_For_LocalArea_plot import *
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Load data

# %%
# Load Line data
LineData = np.load('data/LineData.npy')
LineBloc_space = np.load('data/DemoBloc_space.npy')
# Load PSO estimated most likely TIs
TI_Assignment_Matrix = np.load('data/PSO_TIs.npy', allow_pickle=True)
# Load TIs in MDS coords
MDS_coordinates = np.load('data/MDS_coordinates.npy')
MDS_coordinates_List = np.ndarray.tolist(MDS_coordinates)

# %% [markdown]
# Cacluate P(TI|d)

# %%
# Assign which area to estimate the P(TI|d)
Target_bloc = 3 
Block_distances = np.load('data/demo_distance_matrix.npy')[Target_bloc]

# %%
Candidate_TI_Index, pdf, weights, ratio =Select_TI_For_LocalArea_plot(Num_Selected_TI = 1,
                                                TargetBloc = Target_bloc,
                                                LineBloc_space = LineBloc_space,
                                                TI_Assignment_Matrix = TI_Assignment_Matrix,
                                                Block_distances = Block_distances,
                                                MDS_coordinates_2D = MDS_coordinates,
                                                MDS_coordinates_2D_List=MDS_coordinates_List, 
                                                kde_bw=0.26)
# Out:
# the selected TI [39]
# the selected TI [99]
